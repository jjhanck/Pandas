# %% [markdown]
# # First, we will import the Indeed training data set into Jupyter.
#
# Reading data from CSV with Pandas

# %%
import pandas as pd
import numpy as np
import glob

# To read the files from the specified folder, here the data folder 
#glob(/train_*.csv')

# %%
# Loading the train_features dataset into features variable
features = pd.read_csv('C:\Users\hancojam\Documents\DataMiningNotebooks-master\data/train_features_2013-03-07.csv')
features
# Out:
#                    jobId companyId         jobType       degree        major  \
# 0       JOB1362684407687    COMP37             CFO      MASTERS         MATH
# 1       JOB1362684407688    COMP19             CEO  HIGH_SCHOOL         NONE
# 2       JOB1362684407689    COMP52  VICE_PRESIDENT     DOCTORAL      PHYSICS
# 3       JOB1362684407690    COMP38         MANAGER     DOCTORAL    CHEMISTRY
# 4       JOB1362684407691     COMP7  VICE_PRESIDENT    BACHELORS      PHYSICS
# 5       JOB1362684407692    COMP15         MANAGER     DOCTORAL      COMPSCI
# 6       JOB1362684407693    COMP15             CFO         NONE         NONE
# 7       JOB1362684407694    COMP24          JUNIOR    BACHELORS    CHEMISTRY
# 8       JOB1362684407695    COMP20         JANITOR  HIGH_SCHOOL         NONE
# 9       JOB1362684407696    COMP41  VICE_PRESIDENT    BACHELORS    CHEMISTRY
# 10      JOB1362684407697    COMP56         JANITOR  HIGH_SCHOOL         NONE
# ...

# %%
# Loading the train_salaries dataset into salaries variable
salaries = pd.read_csv('C:\Users\hancojam\Documents\DataMiningNotebooks-master\data/train_salaries_2013-03-07.csv')
salaries
# Out:
#                    jobId  salary
# 0       JOB1362684407687     130
# 1       JOB1362684407688     101
# 2       JOB1362684407689     137
# 3       JOB1362684407690     142
# 4       JOB1362684407691     163
# 5       JOB1362684407692     113
# 6       JOB1362684407693     178
# 7       JOB1362684407694      73
# 8       JOB1362684407695      31
# 9       JOB1362684407696     104
# 10      JOB1362684407697     102
# 11      JOB1362684407698     144
# 12      JOB1362684407699      79
# 13      JOB1362684407700     193
# 14      JOB1362684407701      47
# 15      JOB1362684407702     172
# 16      JOB1362684407703      47
# 17      JOB1362684407704     126
# 18      JOB1362684407705     122
# 19      JOB1362684407706      95
# 20      JOB1362684407707      32
# 21      JOB1362684407708      68
# 22      JOB1362684407709     105
# 23      JOB1362684407710      76
# 24      JOB1362684407711     202
# 25      JOB1362684407712     131
# 26      JOB1362684407713     158
# ...

# %%
# Merging the features and salaries together so that we have a complete data set
df = pd.merge(features, salaries, how='left')
df.head()
# Out:
#               jobId companyId         jobType       degree      major  \
# 0  JOB1362684407687    COMP37             CFO      MASTERS       MATH
# 1  JOB1362684407688    COMP19             CEO  HIGH_SCHOOL       NONE
# 2  JOB1362684407689    COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS
# 3  JOB1362684407690    COMP38         MANAGER     DOCTORAL  CHEMISTRY
# 4  JOB1362684407691     COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS
#
#   industry  yearsExperience  milesFromMetropolis  salary
# 0   HEALTH               10                   83     130
# 1      WEB                3                   73     101
# 2   HEALTH               10                   38     137
# 3     AUTO                8                   17     142
# 4  FINANCE                8                   16     163

# %%
df.head()
# Out:
#               jobId companyId         jobType       degree      major  \
# 0  JOB1362684407687    COMP37             CFO      MASTERS       MATH
# 1  JOB1362684407688    COMP19             CEO  HIGH_SCHOOL       NONE
# 2  JOB1362684407689    COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS
# 3  JOB1362684407690    COMP38         MANAGER     DOCTORAL  CHEMISTRY
# 4  JOB1362684407691     COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS
#
#   industry  yearsExperience  milesFromMetropolis  salary
# 0   HEALTH               10                   83     130
# 1      WEB                3                   73     101
# 2   HEALTH               10                   38     137
# 3     AUTO                8                   17     142
# 4  FINANCE                8                   16     163

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 0 to 999999
# Data columns (total 9 columns):
# jobId                  1000000 non-null object
# companyId              1000000 non-null object
# jobType                1000000 non-null object
# degree                 1000000 non-null object
# major                  1000000 non-null object
# industry               1000000 non-null object
# yearsExperience        1000000 non-null int64
# milesFromMetropolis    1000000 non-null int64
# salary                 1000000 non-null int64
# dtypes: int64(3), object(6)
# memory usage: 76.3+ MB

# %%
#Create a list of Categorical Variables
categ_features = ['jobType, degree, major, industry'];

# %%
education = ['degree'];

# %% [markdown]
# Calculate the median, min and max years of experience, miles from metropolis and salary from the training data set

# %%
print df.yearsExperience.min(), df.milesFromMetropolis.min(), df.salary.min()
# Out:
# 0 0 0

# %%
print df.yearsExperience.median(), df.milesFromMetropolis.median(), df.salary.median()
# Out:
# 12.0 50.0 114.0

# %%
print df.yearsExperience.max(), df.milesFromMetropolis.max(), df.salary.max()
# Out:
# 24 99 301

# %% [markdown]
# Noticed that the minimum salary is zero. Since those zeros represent missing data, we will need to impute a best estimate for those values or remove them. First lets identify how many zeros are in the dataset by creating a dictionary of the counts of the salaries in the dataset

# %%
# Getting count of salary values, especially the 0s
counts = df.salary.value_counts()
dict(counts)
# Out:
# {0: 5,
#  17: 1,
#  18: 3,
#  19: 10,
#  20: 43,
#  21: 49,
#  22: 63,
#  23: 107,
#  24: 129,
#  25: 173,
#  26: 232,
#  27: 309,
#  28: 347,
#  29: 463,
#  30: 518,
#  31: 553,
#  32: 614,
#  33: 743,
#  34: 800,
#  35: 927,
#  36: 1096,
#  37: 1108,
#  38: 1197,
#  39: 1356,
#  40: 1449,
#  41: 1622,
#  42: 1660,
#  43: 1816,
#  44: 1904,
#  45: 2018,
#  46: 2248,
#  47: 2300,
#  48: 2410,
#  49: 2516,
#  50: 2655,
#  51: 2831,
#  52: 3000,
#  53: 3087,
#  54: 3278,
#  55: 3332,
#  56: 3491,
#  57: 3622,
#  58: 3803,
#  59: 4026,
#  60: 4087,
#  61: 4384,
#  62: 4357,
#  63: 4592,
#  64: 4706,
#  65: 4984,
#  66: 5142,
#  67: 5258,
#  68: 5344,
#  69: 5606,
#  70: 5797,
#  71: 5851,
#  72: 6096,
#  73: 6173,
#  74: 6464,
#  75: 6551,
#  76: 6730,
#  77: 6933,
#  78: 7166,
#  79: 7221,
#  80: 7588,
#  81: 7353,
#  82: 7879,
#  83: 7930,
#  84: 8026,
#  85: 8346,
#  86: 8434,
#  87: 8472,
#  88: 8724,
#  89: 8775,
#  90: 9066,
#  91: 9189,
#  92: 9228,
#  93: 9320,
#  94: 9236,
# ...

# %%
#Get Summary Statistics from the Data Frame
df.describe()
# Out:
#        yearsExperience  milesFromMetropolis          salary
# count   1000000.000000       1000000.000000  1000000.000000
# mean         11.992386            49.529260      116.061818
# std           7.212391            28.877733       38.717936
# min           0.000000             0.000000        0.000000
# 25%           6.000000            25.000000       88.000000
# 50%          12.000000            50.000000      114.000000
# 75%          18.000000            75.000000      141.000000
# max          24.000000            99.000000      301.000000

# %%
#Removed the Zero Salary Values
df = df[df.salary != 0]

# %%
df.describe()
# Out:
#        yearsExperience  milesFromMetropolis         salary
# count    999995.000000        999995.000000  999995.000000
# mean         11.992407            49.529381     116.062398
# std           7.212390            28.877721      38.717163
# min           0.000000             0.000000      17.000000
# 25%           6.000000            25.000000      88.000000
# 50%          12.000000            50.000000     114.000000
# 75%          18.000000            75.000000     141.000000
# max          24.000000            99.000000     301.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999995 entries, 0 to 999999
# Data columns (total 9 columns):
# jobId                  999995 non-null object
# companyId              999995 non-null object
# jobType                999995 non-null object
# degree                 999995 non-null object
# major                  999995 non-null object
# industry               999995 non-null object
# yearsExperience        999995 non-null int64
# milesFromMetropolis    999995 non-null int64
# salary                 999995 non-null int64
# dtypes: int64(3), object(6)
# memory usage: 76.3+ MB

# %%
titles = df.jobType.value_counts()
dict(titles)
# Out:
# {'CEO': 124778,
#  'CFO': 124369,
#  'CTO': 125045,
#  'JANITOR': 124971,
#  'JUNIOR': 124592,
#  'MANAGER': 125120,
#  'SENIOR': 125886,
#  'VICE_PRESIDENT': 125234}

# %%
df.head()
# Out:
#               jobId companyId         jobType       degree      major  \
# 0  JOB1362684407687    COMP37             CFO      MASTERS       MATH
# 1  JOB1362684407688    COMP19             CEO  HIGH_SCHOOL       NONE
# 2  JOB1362684407689    COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS
# 3  JOB1362684407690    COMP38         MANAGER     DOCTORAL  CHEMISTRY
# 4  JOB1362684407691     COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS
#
#   industry  yearsExperience  milesFromMetropolis  salary
# 0   HEALTH               10                   83     130
# 1      WEB                3                   73     101
# 2   HEALTH               10                   38     137
# 3     AUTO                8                   17     142
# 4  FINANCE                8                   16     163

# %%
import numpy as np
df = df.replace(to_replace='CEO',value=1)
df = df.replace(to_replace='CTO',value=2)
print df.head()
# Out:
#               jobId companyId         jobType       degree      major  \
# 0  JOB1362684407687    COMP37             CFO      MASTERS       MATH
# 1  JOB1362684407688    COMP19               1  HIGH_SCHOOL       NONE
# 2  JOB1362684407689    COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS
# 3  JOB1362684407690    COMP38         MANAGER     DOCTORAL  CHEMISTRY
# 4  JOB1362684407691     COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS
#
#   industry  yearsExperience  milesFromMetropolis  salary
# 0   HEALTH               10                   83     130
# 1      WEB                3                   73     101
# 2   HEALTH               10                   38     137
# 3     AUTO                8                   17     142
# 4  FINANCE                8                   16     163

# %%
df = df.replace(to_replace='CFO',value=3)
df = df.replace(to_replace='VICE_PRESIDENT',value=4)
df = df.replace(to_replace='SENIOR',value=6)
df = df.replace(to_replace='MANAGER',value=5)
df = df.replace(to_replace='JUNIOR',value=7)
df = df.replace(to_replace='JANITOR',value=8)
print df.head()
# Out:
#               jobId companyId  jobType       degree      major industry  \
# 0  JOB1362684407687    COMP37        3      MASTERS       MATH   HEALTH
# 1  JOB1362684407688    COMP19        1  HIGH_SCHOOL       NONE      WEB
# 2  JOB1362684407689    COMP52        4     DOCTORAL    PHYSICS   HEALTH
# 3  JOB1362684407690    COMP38        5     DOCTORAL  CHEMISTRY     AUTO
# 4  JOB1362684407691     COMP7        4    BACHELORS    PHYSICS  FINANCE
#
#    yearsExperience  milesFromMetropolis  salary
# 0               10                   83     130
# 1                3                   73     101
# 2               10                   38     137
# 3                8                   17     142
# 4                8                   16     163

# %%
df.describe()
# Out:
#              jobType  yearsExperience  milesFromMetropolis         salary
# count  999995.000000    999995.000000        999995.000000  999995.000000
# mean        4.501762        11.992407            49.529381     116.062398
# std         2.290272         7.212390            28.877721      38.717163
# min         1.000000         0.000000             0.000000      17.000000
# 25%         3.000000         6.000000            25.000000      88.000000
# 50%         5.000000        12.000000            50.000000     114.000000
# 75%         6.000000        18.000000            75.000000     141.000000
# max         8.000000        24.000000            99.000000     301.000000

# %%
df.head()
# Out:
#               jobId companyId  jobType       degree      major industry  \
# 0  JOB1362684407687    COMP37        3      MASTERS       MATH   HEALTH
# 1  JOB1362684407688    COMP19        1  HIGH_SCHOOL       NONE      WEB
# 2  JOB1362684407689    COMP52        4     DOCTORAL    PHYSICS   HEALTH
# 3  JOB1362684407690    COMP38        5     DOCTORAL  CHEMISTRY     AUTO
# 4  JOB1362684407691     COMP7        4    BACHELORS    PHYSICS  FINANCE
#
#    yearsExperience  milesFromMetropolis  salary
# 0               10                   83     130
# 1                3                   73     101
# 2               10                   38     137
# 3                8                   17     142
# 4                8                   16     163

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999995 entries, 0 to 999999
# Data columns (total 9 columns):
# jobId                  999995 non-null object
# companyId              999995 non-null object
# jobType                999995 non-null int64
# degree                 999995 non-null object
# major                  999995 non-null object
# industry               999995 non-null object
# yearsExperience        999995 non-null int64
# milesFromMetropolis    999995 non-null int64
# salary                 999995 non-null int64
# dtypes: int64(4), object(5)
# memory usage: 76.3+ MB

# %%
#Group by Salary to Determine Median Salary for Each Job Type to Confirm Proper Ordering
df.groupby(by='jobType').median()
# Out:
#          yearsExperience  milesFromMetropolis  salary
# jobType
# 1                     12                   49     142
# 2                     12                   50     132
# 3                     12                   50     132
# 4                     12                   49     122
# 5                     12                   49     112
# 6                     12                   50     102
# 7                     12                   50      92
# 8                     12                   50      68

# %%
degree = df.degree.value_counts()
dict(degree)
# Out:
# {'BACHELORS': 175495,
#  'DOCTORAL': 175362,
#  'HIGH_SCHOOL': 236975,
#  'MASTERS': 175310,
#  'NONE': 236853}

# %%
df = df.replace(to_replace='DOCTORAL',value=1)
df = df.replace(to_replace='MASTERS',value=2)
df = df.replace(to_replace='BACHELORS',value=3)
df = df.replace(to_replace='HIGH_SCHOOL',value=4)
df = df.replace(to_replace='NONE',value=5)
print df.head()
# Out:
#               jobId companyId  jobType  degree      major industry  \
# 0  JOB1362684407687    COMP37        3       2       MATH   HEALTH
# 1  JOB1362684407688    COMP19        1       4          5      WEB
# 2  JOB1362684407689    COMP52        4       1    PHYSICS   HEALTH
# 3  JOB1362684407690    COMP38        5       1  CHEMISTRY     AUTO
# 4  JOB1362684407691     COMP7        4       3    PHYSICS  FINANCE
#
#    yearsExperience  milesFromMetropolis  salary
# 0               10                   83     130
# 1                3                   73     101
# 2               10                   38     137
# 3                8                   17     142
# 4                8                   16     163

# %%
df.describe()
# Out:
#              jobType         degree  yearsExperience  milesFromMetropolis  \
# count  999995.000000  999995.000000    999995.000000        999995.000000
# mean        4.501762       3.184648        11.992407            49.529381
# std         2.290272       1.423749         7.212390            28.877721
# min         1.000000       1.000000         0.000000             0.000000
# 25%         3.000000       2.000000         6.000000            25.000000
# 50%         5.000000       3.000000        12.000000            50.000000
# 75%         6.000000       4.000000        18.000000            75.000000
# max         8.000000       5.000000        24.000000            99.000000
#
#               salary
# count  999995.000000
# mean      116.062398
# std        38.717163
# min        17.000000
# 25%        88.000000
# 50%       114.000000
# 75%       141.000000
# max       301.000000

# %%
#Group by Salary to Determine Median Salary for Each Job Type to Confirm Proper Ordering
df.groupby(by='jobType').median()
# Out:
#          degree  yearsExperience  milesFromMetropolis  salary
# jobType
# 1             3               12                   49     142
# 2             3               12                   50     132
# 3             3               12                   50     132
# 4             3               12                   49     122
# 5             3               12                   49     112
# 6             3               12                   50     102
# 7             3               12                   50      92
# 8             5               12                   50      68

# %%
major = df.major.value_counts()
dict(major)
# Out:
# {5: 532353,
#  'BIOLOGY': 58379,
#  'BUSINESS': 58518,
#  'CHEMISTRY': 58875,
#  'COMPSCI': 58382,
#  'ENGINEERING': 58594,
#  'LITERATURE': 58684,
#  'MATH': 57800,
#  'PHYSICS': 58410}

# %%
#Tried this to convert none for major to NoneM but no luck. 
#df.loc[df['major'] == 'NONE', 'major'] = 'NoneM'

# %%
major = df.major.value_counts()
dict(major)
# Out:
# {5: 532353,
#  'BIOLOGY': 58379,
#  'BUSINESS': 58518,
#  'CHEMISTRY': 58875,
#  'COMPSCI': 58382,
#  'ENGINEERING': 58594,
#  'LITERATURE': 58684,
#  'MATH': 57800,
#  'PHYSICS': 58410}

# %%
#Coded Around 5 5 for Major Denotes None

df = df.replace(to_replace='BIOLOGY',value=1)
df = df.replace(to_replace='BUSINESS',value=2)
df = df.replace(to_replace='CHEMISTRY',value=3)
df = df.replace(to_replace='COMPSCI',value=4)
df = df.replace(to_replace='ENGINEERING',value=6)
df = df.replace(to_replace='LITERATURE',value=7)
df = df.replace(to_replace='MATH',value=8)
df = df.replace(to_replace='PHYSICS',value=9)

# %%
df.describe()
# Out:
#              jobType         degree          major  yearsExperience  \
# count  999995.000000  999995.000000  999995.000000    999995.000000
# mean        4.501762       3.184648       4.997800        11.992407
# std         2.290272       1.423749       1.871554         7.212390
# min         1.000000       1.000000       1.000000         0.000000
# 25%         3.000000       2.000000       5.000000         6.000000
# 50%         5.000000       3.000000       5.000000        12.000000
# 75%         6.000000       4.000000       5.000000        18.000000
# max         8.000000       5.000000       9.000000        24.000000
#
#        milesFromMetropolis         salary
# count        999995.000000  999995.000000
# mean             49.529381     116.062398
# std              28.877721      38.717163
# min               0.000000      17.000000
# 25%              25.000000      88.000000
# 50%              50.000000     114.000000
# 75%              75.000000     141.000000
# ...

# %%
# 5 for Major = None
major = df.major.value_counts()
dict(major)
# Out:
# {1: 58379,
#  2: 58518,
#  3: 58875,
#  4: 58382,
#  5: 532353,
#  6: 58594,
#  7: 58684,
#  8: 57800,
#  9: 58410}

# %%
df.groupby(by='major').median()
# Out:
#        jobType  degree  yearsExperience  milesFromMetropolis  salary
# major
# 1            4       2               12                   50     125
# 2            4       2               12                   50     132
# 3            4       2               12                   50     126
# 4            4       2               12                   50     129
# 5            5       4               12                   49     100
# 6            4       2               12                   50     135
# 7            4       2               12                   50     122
# 8            4       2               12                   50     130
# 9            4       2               12                   49     127

# %%
df.groupby(by='degree').median()
# Out:
#         jobType  major  yearsExperience  milesFromMetropolis  salary
# degree
# 1             4      5               12                   50     132
# 2             4      5               12                   50     127
# 3             4      5               12                   50     122
# 4             5      5               12                   49      99
# 5             5      5               12                   49      95

# %%
#Industry
industry = df.industry.value_counts()
dict(industry)
# Out:
# {'AUTO': 142941,
#  'EDUCATION': 142819,
#  'FINANCE': 142866,
#  'HEALTH': 142755,
#  'OIL': 142770,
#  'SERVICE': 142639,
#  'WEB': 143205}

# %%
df = df.replace(to_replace='AUTO',value=1)
df = df.replace(to_replace='EDUCATION',value=2)
df = df.replace(to_replace='FINANCE',value=3)
df = df.replace(to_replace='HEALTH',value=4)
df = df.replace(to_replace='OIL',value=6)
df = df.replace(to_replace='SERVICE',value=7)
df = df.replace(to_replace='WEB',value=8)

# %%
df.groupby(by='industry').median()
# Out:
#            jobType  degree  major  yearsExperience  milesFromMetropolis  \
# industry
# AUTO             5       3      5               12                   50
# EDUCATION        5       3      5               12                   50
# FINANCE          4       3      5               12                   50
# HEALTH           4       3      5               12                   50
# OIL              4       3      5               12                   49
# SERVICE          5       3      5               12                   50
# WEB              4       3      5               12                   49
#
#            salary
# industry
# AUTO          108
# EDUCATION      98
# FINANCE       128
# HEALTH        114
# OIL           128
# SERVICE       103
# WEB           119

# %%
#We Have now Created Continuous Variables for all Categorical Variables

# %%
# Import matplot lib
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore', DeprecationWarning)
# %matplotlib inline

# %%
#Lets do Boxplots of Salary Grouped by Job Type
df.boxplot(column='salary', by = 'jobType')

# %%
#Note the big salary difference of the CEO, CFO and CTO jobTypes versus all others.
df.groupby(by=df.jobType<4).mean()
# Out:
#           jobType    degree     major  yearsExperience  milesFromMetropolis  \
# jobType
# False    5.998316  3.297065  4.998373        11.987942            49.520638
# True     1.998907  2.996641  4.996841        11.999874            49.544001
#
#              salary
# jobType
# False    102.495634
# True     138.751611

# %%
#Lets Try to Identify "C Suite Jobs" Versus All Others
#Here we've grouped by job type. Job Types of 3 and less are the CEO, CTO and CFO Job Types
df_2 = df.groupby(by=df.jobType<4).mean()
ax = df_2.plot(kind='barh')

# %%
#Lets do Boxplots of  Grouped by Job Type
df.boxplot(column='salary', by = 'industry')

# %%
# No of jobTypes per Industry
jobCount = pd.crosstab(df['industry'],df['jobType'])
print jobCount
# Out:
# jobType        1      2      3      4      5      6      7      8
# industry
# AUTO       17908  17789  17614  17814  18104  17818  17812  18082
# EDUCATION  17838  17911  17655  17724  17770  18075  17975  17871
# FINANCE    17913  17773  17858  17904  17958  17902  17759  17799
# HEALTH     17626  17668  17976  18140  17733  17945  17954  17713
# OIL        17883  18077  17683  17866  17881  18190  17495  17695
# SERVICE    17703  17943  17651  17855  17861  18014  17759  17853
# WEB        17907  17884  17932  17931  17813  17942  17838  17958

# %% [markdown]
# Refernce:
# Industry
#    AUTO	    1
# EDUCATION	2
# FINANCE	    3
# HEALTH	    4
# OIL	        6
# SERVICE 	7
# WEB	        8

# %%
# Grouping by Industry to see salary range per Industry
# Group by Industry and jobType and get min, max of salary
df_ind_jType = df.groupby(by=['industry','jobType'])
salMin = df_ind_jType.salary.min()
salMax = df_ind_jType.salary.max()
print salMin 
print salMax
# Out:
# industry   jobType
# AUTO       1          61
#            2          59
#            3          57
#            4          52
#            5          44
#            6          41
#            7          31
#            8          25
# EDUCATION  1          55
#            2          51
#            3          51
#            4          44
#            5          37
#            6          31
#            7          23
#            8          17
# FINANCE    1          78
#            2          69
#            3          71
#            4          64
#            5          56
#            6          49
#            7          45
#            8          36
# HEALTH     1          70
#            2          60
#            3          62
#            4          53
#            5          49
#            6          42
#            7          36
#            8          28
# OIL        1          76
#            2          71
#            3          70
#            4          65
# ...

# %%
# need to find a nice way to plot the above
# Next plot - range of salary per job type per industry and compare.. Meaning salary range of CEOs across all industries
# find a way to incorporate years of experience in these plots

# %%
# Bar Graph of job Type 1-3 vs Job Type 4 and above
# Salary of Executive job types vs Others
df_cjob = df.groupby(by=df.jobType<4).mean()
jobSal = df_cjob.salary
ax = jobSal.plot(kind='barh')
ax.set_xlabel("Salary")
ax.set_ylabel("Executive Jobs vs Others")

# %%
#Lets do Boxplots of  Grouped by Industry
df.boxplot(column='salary', by = 'jobType')

# %%
#Lets do Boxplots of  Grouped by jobType, YearsExp
df.boxplot(column='salary', by = 'yearsExperience')

# %%
# Scatter plot matrix
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore', DeprecationWarning)
# %matplotlib inline

# %%
from pandas.tools.plotting import scatter_matrix
ax1 = scatter_matrix(df, figsize=(15,10), diagonal='kde')
#scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')

# %%
import seaborn as sns
cmap = sns.diverging_palette(220,10, as_cmap=True)

# %%
vars_to_plot_separate = [['degree','jobType','degree','major','yearsExperience','milesFromMetropolis']]
for index, plot_vars in enumerate(vars_to_plot_separate):
    plt.figure(figsize=(4,4))
    ax2=df.boxplot(column=plot_vars, by='salary')
plt.show()

# %%
df.info()

# %%
#Plot the correlation matrix using seaborn
sns.set(style="darkgrid")
f, ax = plt.subplots(figsize=(9,9))
sns.corrplot(df,
            annot=True,
            sig_stars=True,
            cmap=cmap,
            ax=ax)
f.tight_layout()
